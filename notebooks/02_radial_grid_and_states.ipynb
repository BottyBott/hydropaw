# %% [markdown]
# # Radial Grid and States
#
# Visualize the radial grid density and list the valence / projector states described in the PAW dataset.

# %%
import sys
from pathlib import Path

root = Path.cwd().resolve()
if (root / 'src').exists():
    sys.path.append(str(root))
else:
    sys.path.append(str(root.parent))

# %%
from pathlib import Path

import matplotlib.pyplot as plt

from src.pawparse import parse_paw_xml
from src.plots import plot_radial_grid, plot_radial_spacing

dataset = parse_paw_xml(Path("../data/H.GGA_PBE-JTH.xml"))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plot_radial_grid(dataset.df_grid, ax=axes[0])
plot_radial_spacing(dataset.df_grid, ax=axes[1])
fig.tight_layout()
dataset.df_valence
# Out:
#    id    n  l    f       rc         e
# 0  H1  1.0  0  1.0  0.99495 -0.238602
# 1  H2  NaN  0  NaN  0.99495  6.000000
# 2  H3  NaN  1  NaN  0.99495  1.250000
