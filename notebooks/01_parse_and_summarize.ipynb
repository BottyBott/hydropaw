# %% [markdown]
# # Parse and Summarize
#
# This notebook extracts tidy tables from the PAW XML and inspects the metadata, energy budget, cutoff tiers, and valence states.

# %%
import sys
from pathlib import Path

root = Path.cwd().resolve()
if (root / 'src').exists():
    sys.path.append(str(root))
else:
    sys.path.append(str(root.parent))

# %%
from pathlib import Path

import pandas as pd

from src.pawparse import parse_paw_xml

dataset = parse_paw_xml(Path("../data/H.GGA_PBE-JTH.xml"))
dataset.df_energy
# Out:
#    kinetic_Ha     xc_Ha  electrostatic_Ha  total_Ha
# 0    0.447266 -0.251365         -0.654835 -0.458935
